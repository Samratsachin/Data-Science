# %% [markdown]
# <a href="https://colab.research.google.com/github/Samratsachin/Data-Science/blob/main/Applied_Analysis_of_Central_Tendency_in_Real_World_Wine_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Load Numpy and Pandas for Manipulating numbers and data Frames
#Load Matplotlib.pyplot and seaborn for data Visualization

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read in the " WineQuality write.csv" file as pandas DataFrame
data = pd.read_csv('/content/Data Sets/Wine Quality Dataset.csv')

# %%
# Take a brief look at the data set
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
# Get the Dimensions of the Data Sets
data.shape
# Out:
# (4898, 12)

# %%
# Get the row names of the data frame
data.index
# Out:
# RangeIndex(start=0, stop=4898, step=1)

# %%
#Get the colunms names of the data frames
data.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
# Look at the basic information reside in the data frame
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
# Create a hisogram of the "Fixed acidity" feature
plt.figure(figsize = (11,5))
sns.histplot(data = data, x = 'fixed acidity', color = 'orange', edgecolor = 'linen', alpha = 0.5, bins = 5)
plt.title("Histogram of fixed Acidity")
plt.xlabel("Fixed Acicidity")
plt.ylabel('count')
plt.show()

# %%
# Calculate the mean of fixed acidity feature
round(data['fixed acidity'].mean(),2)
# Out:
# np.float64(6.85)

# %%
#Calculate the median of "fixed acidity feature "
data['fixed acidity'].median()
# Out:
# 6.8

# %%
# Create A histogram of the "Fixed acidity feature and also show the mean and median"
plt.figure(figsize = (11,6))
sns.histplot(data = data, x='fixed acidity', color = 'orange', edgecolor ='linen', alpha = 0.5, bins = 5)
plt.title("Histogram Of Fixed Acidity")
plt.xlabel("Fixed Acicdity")
plt.ylabel('count')
plt.vlines(data['fixed acidity'].mean(), ymin = 0, ymax=4000, colors='blue', label='mean')
plt.vlines(data['fixed acidity'].median(),ymin=0,ymax =4000, colors = 'red',label='median')
plt.legend()
plt.show()

# %%
# CReate a histogram of the "Volatile Acidity" feature
plt.figure(figsize=(11,6))
sns.histplot(data = data, x = 'volatile acidity', color = 'green', edgecolor = 'linen', alpha = 0.5, bins = 5)
plt.title("Histogram of volatile Acidity")
plt.xlabel("volatile Acidity")
plt.ylabel('count')
plt.show()

# %%
#Plot distplot using Volatile acidity feature
plt.figure(figsize=(11,6))
sns.distplot(data['volatile acidity'],color = 'blue', )
plt.title("Distplot of Volatile Acidity")
plt.xlabel("volatile Acidity")
plt.ylabel('density')
plt.show()
# Out:
# /tmp/ipython-input-2279032260.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['volatile acidity'],color = 'blue', )

# %%
# Calculate Skewness of Volatile Acicdity
data['volatile acidity'].skew()
# Out:
# np.float64(1.5769795029952025)

# %%
#Calculate the mean of Volatile acidity feature
data['volatile acidity'].mean()
# Out:
# np.float64(0.27824111882400976)

# %%
#Calculate the median of Volatile acidity feature
data['volatile acidity'].median()
# Out:
# 0.26

# %%
#Create a histogram of the volatile acidity Feature and also shoe the mean and meadian
plt.figure(figsize = (11,6))
sns.histplot( data = data, x ='volatile acidity', color ='green', edgecolor = 'linen', alpha=0.5, bins =5)
plt.title("Histogram of Volatile Acidity")
plt.xlabel("volatile acidity")
plt.ylabel('density')
plt.vlines(data['volatile acidity'].mean(), ymin = 0, ymax = 4000, colors = 'blue', label = 'mean')
plt.vlines(data['volatile acidity'].median(), ymin = 0, ymax = 4000, colors = 'red', label = 'median')
plt.legend()
plt.show()

# %%
# Create a histogram of the Citric Acid feature
plt.figure(figsize=(11,6))
sns.histplot(data = data, x = 'citric acid', color = 'red', edgecolor = 'linen', alpha = 0.5, bins = 5)
plt.title(" Histogram of Citric Acid")
plt.xlabel("Citric Acid")
plt.ylabel('count')
plt.show()

# %%
# Calculate the mean of Citric acid Feature
data['citric acid'].mean()
# Out:
# np.float64(0.33419150673744386)

# %%
# Calculate the median of Citric acid Feature
data['citric acid'].median()
# Out:
# 0.32

# %%
#Create A histogram of the 'Citrric Acid'
plt.figure(figsize=(11,6))
sns.histplot(data = data,  x = 'citric acid', color ='red', edgecolor ='linen', alpha=0.5, bins = 5)
plt.title("Histogram of the citric acid feature")
plt.xlabel("Citric Acid")
plt.ylabel('count')
plt.vlines(data['citric acid'].mean(),ymin = 0, ymax = 4000, colors = 'blue', label = 'mean')
plt.vlines(data['citric acid'].median(),ymin = 0, ymax = 4000, colors = 'red', label = 'median')
plt.legend()
plt.show()

# %%
# Calculate Distplot using Citric acid feature
plt.figure(figsize=(11,6))
sns.distplot(data['citric acid'], color = 'blue')
plt.title("Distplot of teh Citric Acid Feature")
plt.xlabel("Citric Acid")
plt.ylabel('density')
plt.show()
# Out:
# /tmp/ipython-input-2393731966.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['citric acid'], color = 'blue')

# %%
plt.figure(figsize=(11, 6))
sns.countplot(x='quality', data=data)  # corrected this line
plt.title('Count Plot of the Quality')
plt.xlabel("Quality")
plt.ylabel('Count')
plt.show()

# %%
# Count the no of Occurences of diffrent categories of the quality feature
data['quality'].value_counts()
# Out:
# quality
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: count, dtype: int64

# %%
# Calculate the mode of thr "quality Feature"
data['quality'].value_counts().index[0]
# Out:
# np.int64(6)

# %%
# Create a new pandas series called "rep_acid" that conatins the details of the reprsentive Quality for the different types of acids
rep_acid = pd.Series(index=['fixed acidity', 'volatile acidity','citric acid','quality'],data=[data['fixed acidity'].mean(),data['volatile acidity'].mean(),data['citric acid'].mean(),data['quality'].value_counts().index[0]])

# %%
# Print the "rep_acid" Series
rep_acid
# Out:
# fixed acidity       6.854788
# volatile acidity    0.278241
# citric acid         0.334192
# quality             6.000000
# dtype: float64
